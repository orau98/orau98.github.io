# %%
import subprocess
result = subprocess.run(
    ['node', 'scripts/extract_kamikiri_hostplants.mjs'],
    cwd='/Users/akimotohiroki/orau98.github.io',
    capture_output=True,
    text=True,
    timeout=120
)
print(result.stdout)
if result.stderr:
    print('STDERR:', result.stderr[:3000])
